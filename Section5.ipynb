# %% [markdown]
# # Section 5

# %% [markdown]
# ## Smoke Test

# %% [markdown]
# A very simple test to check if something is working. It doesn't check into detail

# %% [markdown]
# ## Where to deploy?

# %% [markdown]
# * In house server
# * Cloud (AWS, Google)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It isn't allow to upload the artifact to the AWS web service but AWS Storage Service (AWS S3)

# %% [markdown]
# There is a AWS S3 exist already which use for the web service so it need to create another one.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## GitLab Group Settings

# %% [markdown]
# * Organize projects in folders
# * Set permissions and settings for the group

# %% [markdown]
# | ![image.png](attachment:image.png) | ![image-2.png](attachment:image-2.png) |
# | --- | --- |

# %% [markdown]
# | ![image.png](attachment:image.png) | ![image-2.png](attachment:image-2.png) |
# | --- | --- |

# %% [markdown]
# Create a key for AWS S3 name

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Credentials

# %% [markdown]
# IAM = Identity and Access Management

# %% [markdown]
# | ![image.png](attachment:image.png) | ![image-2.png](attachment:image-2.png) |
# | --- | --- |

# %% [markdown]
# | ![image.png](attachment:image.png) | ![image-2.png](attachment:image-2.png) |
# | --- | --- |

# %% [markdown]
# Create CI/CD Variables

# %% [markdown]
# ![image.png](attachment:image.png)
