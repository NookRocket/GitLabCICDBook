# %% [markdown]
# # Section 4 : YAML

# %% [markdown]
# It contains data in a pair of key and value

# %% [markdown]
# ### Disable Job

# %% [markdown]
# `.` put a comma in front of a job name

# %% [markdown]
# ```yml
# .deploy review:
#   stage: deploy review
# ```

# %% [markdown]
# ### Anchors

# %% [markdown]
# ##### Assign a value

# %% [markdown]
# ```yml
# name: &name Jane
# self: *name
# ```

# %% [markdown]
# ##### Assign properties

# %% [markdown]
# ```yml
# base_person: &base
#   city: nyc
#   country: usa
#
# person:
#   <<: *base
# ```

# %% [markdown]
# ### Validate the CI file

# %% [markdown]
# To double check if the yaml has validated syntax

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
